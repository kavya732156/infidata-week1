# %% [markdown]
# # matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,6])
y=np.array([0,250])
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,8,1,10])
plt.plot(x,y)
plt.show()

# %% [markdown]
# # To modify the inteval values: we specified parameter (1,10,2) means 1: minimum value and 10: maximaum value and 2: interval
# ## values always depend on x-axis

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,8,1,10])
x_ticks=np.arange(1,10,2)
plt.xticks(x_ticks)
y_ticks=np.arange(1,10,2)
plt.yticks(y_ticks)
plt.plot(x,y)
plt.show()

# %% [markdown]
# # we dont wont linear line insted of that it will have dot line  (o) reprents the ring

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,8])
y=np.array([3,10])
plt.plot(x,y,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,8,1,10])
plt.plot(x,y,'o')
plt.show()

# %% [markdown]
# # when we dont have x-coordinator it will take default value os 0,1,2 3,..... but for y-axies it will not happens

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y)
plt.show()

# %% [markdown]
# # Reprents with line and dot (o) marker='o' is used

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='o')
plt.show()

# %% [markdown]
# # you can use any symbol (+,D ,d,*,......)in marker method

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='D')
plt.show()

# %% [markdown]
# # using a  1 as acts as tripdown (upper arrow key )
# # 2 acts tripup ( lower key)

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='1')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='2')
plt.show()

# %% [markdown]
# # increse the size of marker sixe

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='o',ms='10')
plt.show()

# %% [markdown]
# # apply edge color by mec(merker edge colour) method

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='o',ms=10,mec='r')
plt.show()

# %% [markdown]
# # filling the color (marker face color)mfc

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='o',ms=10,mfc='r')
plt.show()

# %% [markdown]
# # to add color to the line also by by passing mec and mfc

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='o',ms=15,mec='#FF0000',mfc='#FF0000')
plt.show()

# %% [markdown]
# # changing the line style by specifing linestyle method

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='o',ms=15,mec='#FF0000',mfc='#FF0000',linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='o',ms=15,mec='#FF0000',mfc='#FF0000', linestyle='dashed')
plt.show()

# %% [markdown]
# # shorter syntax is ls

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='o',ms=15,mec='#FF0000',mfc='#FF0000', ls=':')
plt.show()

# %% [markdown]
# # to change the color for the line

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='o',ms=15,mec='#FF0000',mfc='#FF0000',color='#102423')
plt.show()

# %% [markdown]
# # to increse the width of the line by linewidth

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='o',ms=15,mec='#FF0000',mfc='#FF0000',color='#102423',linewidth='5')
plt.show()

# %% [markdown]
# # taking two y axis with default x axis

# %%
import matplotlib.pyplot as plt
import numpy as np
y1=np.array([3,8,1,10])
y2=np.array([6,2,7,11])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %% [markdown]
# # ploting x1 with y1 and x2 and y2

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=np.array([1,2,6,8])
x2=np.array([1,8,9,12])
y1=np.array([0,7,3,1])
y2=np.array([6,2,7,4])
plt.plot(x1,y1,x2,y2)
plt.show()

# %% [markdown]
# # how to label  for the axis

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,120,125])
y=np.array([240,250,260,270,280,300,310,320,330])
plt.plot(x,y)
plt.xlabel("Pulse")
plt.ylabel("Calorie")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,120,125])
y=np.array([240,250,260,270,280,300,310,320,330])
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'red','size':20}
plt.plot(x,y)
plt.title("sport Watch",fontdict=font1)
plt.xlabel("Pulse",fontdict=font1)
plt.ylabel("Calorie",fontdict=font2)
plt.show()

# %% [markdown]
# # serif an extension version

# %% [markdown]
# # changing the position loc is used

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,120,125])
y=np.array([240,250,260,270,280,300,310,320,330])
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'red','size':20}
plt.plot(x,y)
plt.title("sport Watch",loc='left',fontdict=font1)
plt.xlabel("Pulse",fontdict=font1)
plt.ylabel("Calorie",fontdict=font2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,120,125])
y=np.array([240,250,260,270,280,300,310,320,330])
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'red','size':20}
plt.plot(x,y)
plt.title("sport Watch",loc='left',fontdict=font1)
plt.xlabel("Pulse",fontdict=font1)
plt.ylabel("Calorie",fontdict=font2)
plt.show()

# %% [markdown]
# # grides horizontally

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,120,125])
y=np.array([240,250,260,270,280,300,310,320,330])
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'red','size':20}
plt.plot(x,y)
plt.title("sport Watch",fontdict=font1)
plt.xlabel("Pulse",fontdict=font1)
plt.ylabel("Calorie",fontdict=font2)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,120,125])
y=np.array([240,250,260,270,280,300,310,320,330])
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'red','size':20}
plt.plot(x,y)
plt.title("sport Watch",fontdict=font1)
plt.xlabel("Pulse",fontdict=font1)
plt.ylabel("Calorie",fontdict=font2)
plt.grid(axis='x')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,120,125])
y=np.array([240,250,260,270,280,300,310,320,330])
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'red','size':20}
plt.plot(x,y)
plt.title("sport Watch",fontdict=font1)
plt.xlabel("Pulse",fontdict=font1)
plt.ylabel("Calorie",fontdict=font2)
plt.grid(color='red', linestyle='--',linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,120,125])
y=np.array([240,250,260,270,280,300,310,320,330])
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'red','size':20}
plt.plot(x,y)
plt.title("sport Watch",fontdict=font1)
plt.xlabel("Pulse",fontdict=font1)
plt.ylabel("Calorie",fontdict=font2)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # how to apply a subplots .subplot means u can draw multiple plots in single axis
# ### 1.subplot(1,2,1) means 1 row 2 columns and that is plot1
# ### 2.subplot(1,2,2) means 1 row 2 columns and that is plot2

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %% [markdown]
# # create 2 rows 1 colums

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)
#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.show()

# %% [markdown]
# # you can add titles

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("sales")
#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("profit")
plt.show()

# %% [markdown]
# # super titles

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("sales")
#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("profit")
plt.suptitle("My Shop")
plt.show()

# %% [markdown]
# #  creating/plotting  a scatter ,scatter it plot larger data

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot1
x=np.array([5,7,2,1,12,4,5,1,22,30,6,8])
y=np.array([99,89,87,88,34,56,99,112,112,110,35,99])
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot1
x=np.array([5,7,2,1,12,4,5,1,22,30,6,8])
y=np.array([99,89,87,88,34,56,99,112,112,110,35,99])
plt.scatter(x,y,color='#16A679')
x=np.array([1,9,7,8,5,6,7,3,5,11,12,9])
y=np.array([100,99,98,66,99,0,123,121,66,53,12,45])
plt.scatter(x,y,color='#DCF72D')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(['A','B','C','D'])
y=np.array([3,6,8,9])
plt.barh(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(['A','B','C','D'])
y=np.array([3,6,8,9])
plt.barh(x,y,color='red')
plt.show()
